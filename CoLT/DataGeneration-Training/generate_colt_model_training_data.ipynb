# %%
import json
import random
from statistics import mean
import numpy as np
import sys
import os
import joblib
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import KFold
from sklearn.compose import TransformedTargetRegressor
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin
import matplotlib.pyplot as plt
from itertools import accumulate
import pickle
from pathlib import Path
import datetime

from tqdm import tqdm

# %%
def filterEventProb(m, mLeft, byLeft):
    #See if this event is possible, given the current state
    # m is the TurnEvent
    # mLeft is the player's number of cards left
    # byLeft is the number of bystander cards left

    # print(f'**FILTER EVENT PROB for mine={mLeft}, by={byLeft}')
    # m.printEvent()

    #It isn't possible if m.mine is greater than mLeft
    if m.mine > mLeft:
        # print('  0 -> too many of mine')
        return 0.0
    
    #It isn't possible if m.mine equals mLeft and m.bad is not None
    if m.mine == mLeft and m.bad:
        # print('  0 -> all mine + bad')
        return 0.0

    #It isn't possible if m.bad is 'by' and byLeft is 0
    if m.bad == 'by' and byLeft == 0:
        # print('  0 -> no by left')
        return 0.0
    
    #We don't have to check if it is theirs or assassin, because if 
    #there weren't at least 1 of those cards, the game would already be over

    # print('  ', m.p, ' -> unfiltered')
    return m.p

# %%
def getEventProbs(pM, mLeft, byLeft):
    #pM is the player's TurnEvent list
    #mLeft is the player's number of cards left
    #byLeft is the number of bystander cards left
    # This function will compute and return a new distribution 
    # over the TurnEvents in pM, given the context, 
    # i.e. restricting ourselves to only possible turnEvents

    x = list(range(36))
    x2 = [i+36 for i in x]
    p_prior = [m.p for m in pM]
    


    #Filter probs by possibility
    mProbsUN = np.asarray([filterEventProb(m, mLeft, byLeft) for m in pM])
    #Renormalize and return
    mProbs = mProbsUN / mProbsUN.sum()
    if np.isnan(mProbs).any():
        print('ERROR, THIS IS WHAT WE HAVE HERE!!!!')
        print('Mine left: ', mLeft)
        print('By Left: ', byLeft)
        for i, m in enumerate(pM):
            m.printEvent()
            print(' => Post prob : ', mProbs[i])

    # if mLeft < 3:
    #     plt.bar(x,p_prior,color='r',label='prior')
    #     plt.bar(x2,list(mProbs),color='b',label='post')
    #     plt.legend()
    #     plt.title(f'Probs for my left : {mLeft} by left : {byLeft}')
    #     plt.show()
    return mProbs

# %%
def simulateGame(pA, pB, aLeft, bLeft, byLeft):
    # Complete a game from this state, where 
    # pA and pB are the player's TurnEvent lists (distributions over outcomes for single turn)
    # aLeft is the number of cards A has left
    # bLeft is the number of cards B has left
    # byLeft is the number of bystander cards left
    #Return True if A wins this game simulation

    # Create the probabilities to draw from
    AProbs = [a.p for a in pA]
    BProbs = [b.p for b in pB]
    
    #Whose turn is it?  Assume it is A's (can easily pass this in to be more general)
    ATurn = True

    # print('Simulating Game')

    #Sit in this loop until the game ends and something is returned
    while True:
        # print(f'[a:{aLeft} | by:{byLeft} | b:{bLeft}]: A Turn? {ATurn}')
        if ATurn:
            #What does A do this turn?
            #Draw their turn result
            AProbs = getEventProbs(pA, aLeft, byLeft)
            turnResult = np.random.choice(pA, p=AProbs)
            # turnResult.printEvent()  #Display it out
            aLeft -= turnResult.mine  #Adjust state by how many of their cards they got
            # This happens first, because turn ends if bad thing happens
            if aLeft <= 0:
                # print(' A won normally')
                return True, 0 #A won
            if turnResult.bad:
                #Something bad happened, adjust state accordingly
                if turnResult.bad == 'theirs':
                    bLeft -= 1
                if turnResult.bad == 'by':
                    byLeft -= 1
                if turnResult.bad == 'assassin':
                    # print(' B won by assassin')
                    return False, 1

            #If A lost by turning over other things, return False
            #If all the bystanders are turned over, that doesn't matter
            if bLeft == 0:
                # print('  B won by A choosing b')
                return False, 0

        else:
            #Same as above, but flipped for player B (trues become falses, and vice versa)
            #What does B do this turn?
            BProbs = getEventProbs(pB, bLeft, byLeft)
            turnResult = np.random.choice(pB, p=BProbs)
            # for i, t, in enumerate(pB):
            #     print(f'***{i}***')
            #     t.printEvent()
            #     print(f'   p={BProbs[i]}')
            # print('+++SELECTED++++')
            # turnResult.printEvent()
            bLeft -= turnResult.mine
            if bLeft <= 0:
                # print(' B won normally')
                return False, 0 
            if turnResult.bad:
                if turnResult.bad == 'theirs':
                    aLeft -= 1
                if turnResult.bad == 'by':
                    byLeft -= 1
                if turnResult.bad == 'assassin':
                    # print(' A won by assassin')
                    return True, 1

            if aLeft == 0:
                # print('  A won by B choosing a')
                return True, 0

        #Switch whose turn it is
        ATurn = not ATurn

# %%
def calculateWinPercentage(pA, pB, aLeft, bLeft, byLeft, N):
    #Estimate the win percentage for player A, where the inputs are:
    #  - pA is the list of A's TurnEvents
    #  - pB is the list of B's TurnEvents
    #  - aLeft is the number of cards A has left
    #  - bLeft is the number of cards B has left
    #  - byLeft is the number of bystander cards left

    assassinWins = 0
    Awins = 0
    for i in range(N):
        Awin, assassinWin = simulateGame(pA, pB, aLeft, bLeft, byLeft)
        assassinWins += assassinWin
        if Awin:
            Awins += 1

    # print(f'{assassinWins} assassin wins out of {N} games.')
    return Awins/N, assassinWins

# %%
class TurnEvent():
    def __init__(self, mine, bad, P):
        self.mine = mine
        self.bad = bad
        self.p = P

    def printEvent(self):
        print('[TurnEvent] (P =', round(self.p,4), ') Mine: ', self.mine, 'Bad: ', self.bad)

# %%
def create_string(arr):
    res = ''
    for num in arr:
        res += str(num)
    return res

# %%
#Generates all the possible events
def generate_pos_events():
    res = []
    for r in range(10):
        c = 0
        for b in [None, 'theirs', 'by', 'assassin']:
            
            if r == 0 and (b is None):
                c += 1
                continue
            if r == 9 and (b is not None):
                c += 1
                continue

            key = [r, 0, 0, 0]
            if c > 0:
                key[c] = 1
            c += 1
            res.append(create_string(key))
    return res
pos_events = generate_pos_events()

# %%
def create_events(pos_events,probs):
    #We pass in pos_events because order matters
    P = []

    for event, p in zip(pos_events,probs):
        r = int(event[0])
        if int(event[1]) == 1:
            b = "theirs"
        elif int(event[2]) == 1:
            b = "by"
        elif int(event[3]) == 1:
            b = "assassin"
        else:
            b = None

        newEvent = TurnEvent(r, b, p)
        P.append(newEvent)
    return P

# %%
def create_vector(AP, BP):
    return np.array(AP) - np.array(BP)

# %%
#This function will create a random distribution over outcomes
#Hand tuned to give reasonable vectors
def createRandomProbVector(n):
    #Default high value
    # S = 7
    S = np.random.randint(low=1,high=9)

    #scaler for high value for good things
    # m = 4
    m = np.random.randint(low=1, high=5)

    #scaler for high value for getting one right
    # w = 9
    w = np.random.randint(low=2,high=12)

    #high value for all the assassins
    # A = 2
    A = np.random.randint(low=1, high=8)
    h = S*np.ones(n)
    #Default high for all stats is 2, besides those listed
    h[0] = m*S   #1 Blue
    h[1] = m*S   #1 Bystander
    h[3] = w*S   #1 Correct
    h[4] = m*S   #1 Correct & 1 Blue
    h[5] = m*S   #1 Correct & 1 Bystander
    h[7] = m*S   #2 Correct
    h[8] = m*S   #2 Correct & 1 Blue
    h[9] = m*S   #2 Correct & 1 Bystander
    h[11] = m*S   #3 Correct
    h[12] = m*S   #3 Correct & 1 Blue
    h[13] = m*S   #3 Correct & 1 Bystander

    ai = 2
    while ai < 36:
        h[ai] = A
        ai += 4

    low = np.zeros(n)
    low[3] = 1

    valid = False
    while not valid:
        p = np.random.randint(low,high=h,size=n)

        if np.sum(p) > 0:
            valid = True
    p = p/np.sum(p)
    return p

# %%
def create_data_set(M, N):
    #M is the number of data points to have in this set
    #N is the number of samples to use to estimate the win percentage
    #This function will create and save a new data set file
    x_vals = []
    prob_y_vals = []
    for m in range(M):
        #Create a random A prob vector
        pA = createRandomProbVector(36)
        eA = create_events(pos_events, pA)
        # for e in eA:
            # e.printEvent()
        #Create a random B prob vector
        pB = createRandomProbVector(36)
        eB = create_events(pos_events, pB)
        #Get the win probability between them
        aLeft = 9
        bLeft = 8
        byLeft = 7

        AwinP, aw = calculateWinPercentage(eA, eB, aLeft, bLeft, byLeft, N)
        print(m, ' => ', AwinP, 'assassin wins: ', aw)
        #Create data samples (A vs B) 
        #Add to x_vals, and the corresponding wp/category into y_vals
        x_vals.append(create_vector(pA,pB))
        prob_y_vals.append(AwinP)
   
    nowTime = datetime.datetime.now ().strftime ('%Y-%m-%d-%H-%M-%S')
    filename = 'data\COLTModelData' + nowTime

    np.save(filename + 'X.npy', x_vals)
    np.save(filename + 'Y.npy', prob_y_vals)

# %%
#Create the datasets
num_data_sets = 1
N = 1000
M = 2000

for d in range(num_data_sets):
    create_data_set(M, N)
    print('Created dataset', d)
print('Done creating all datasets')
# Out:
# 0  =>  0.297 assassin wins:  433
# 1  =>  0.37 assassin wins:  246
# 2  =>  0.305 assassin wins:  0
# 3  =>  0.636 assassin wins:  315
# 4  =>  0.871 assassin wins:  977
# 5  =>  0.398 assassin wins:  919
# 6  =>  0.567 assassin wins:  572
# 7  =>  0.571 assassin wins:  343
# 8  =>  0.457 assassin wins:  448
# 9  =>  0.966 assassin wins:  893
# 10  =>  0.586 assassin wins:  427
# 11  =>  0.412 assassin wins:  446
# 12  =>  0.431 assassin wins:  240
# 13  =>  0.749 assassin wins:  114
# 14  =>  0.0 assassin wins:  998
# 15  =>  0.627 assassin wins:  374
# 16  =>  0.698 assassin wins:  34
# 17  =>  0.903 assassin wins:  837
# 18  =>  0.172 assassin wins:  399
# 19  =>  0.585 assassin wins:  485
# 20  =>  0.455 assassin wins:  374
# 21  =>  0.001 assassin wins:  960
# 22  =>  0.095 assassin wins:  804
# 23  =>  0.759 assassin wins:  997
# 24  =>  0.347 assassin wins:  276
# 25  =>  0.364 assassin wins:  665
# 26  =>  0.228 assassin wins:  770
# 27  =>  0.445 assassin wins:  342
# 28  =>  0.282 assassin wins:  641
# 29  =>  0.398 assassin wins:  419
# 30  =>  0.561 assassin wins:  0
# 31  =>  0.514 assassin wins:  592
# 32  =>  0.052 assassin wins:  998
# 33  =>  0.328 assassin wins:  677
# 34  =>  0.575 assassin wins:  663
# 35  =>  0.992 assassin wins:  974
# 36  =>  0.812 assassin wins:  588
# 37  =>  0.32 assassin wins:  578
# 38  =>  0.06 assassin wins:  964
# 39  =>  0.481 assassin wins:  464
# 40  =>  0.515 assassin wins:  348
# 41  =>  0.959 assassin wins:  983
# 42  =>  0.818 assassin wins:  700
# 43  =>  0.117 assassin wins:  845
# 44  =>  0.774 assassin wins:  812
# 45  =>  0.817 assassin wins:  968
# 46  =>  0.56 assassin wins:  638
# 47  =>  0.628 assassin wins:  666
# 48  =>  0.838 assassin wins:  807
# 49  =>  0.363 assassin wins:  198
# 50  =>  0.611 assassin wins:  147
# 51  =>  0.52 assassin wins:  301
# 52  =>  0.736 assassin wins:  249
# 53  =>  0.173 assassin wins:  808
# 54  =>  0.319 assassin wins:  974
# 55  =>  0.585 assassin wins:  280
# 56  =>  0.334 assassin wins:  788
# 57  =>  0.2 assassin wins:  935
# 58  =>  0.055 assassin wins:  933
# 59  =>  0.347 assassin wins:  448
# 60  =>  0.62 assassin wins:  480
# 61  =>  0.472 assassin wins:  535
# 62  =>  0.272 assassin wins:  439
# 63  =>  0.152 assassin wins:  768
# 64  =>  0.617 assassin wins:  384
# 65  =>  0.474 assassin wins:  210
# 66  =>  0.533 assassin wins:  136
# 67  =>  0.118 assassin wins:  0
# 68  =>  0.188 assassin wins:  811
# 69  =>  0.336 assassin wins:  439
# 70  =>  0.626 assassin wins:  287
# 71  =>  0.188 assassin wins:  779
# 72  =>  0.707 assassin wins:  494
# 73  =>  0.612 assassin wins:  630
# 74  =>  0.553 assassin wins:  267
# 75  =>  0.075 assassin wins:  857
# 76  =>  0.475 assassin wins:  530
# 77  =>  0.394 assassin wins:  134
# 78  =>  0.687 assassin wins:  373
# 79  =>  0.637 assassin wins:  461
# 80  =>  0.633 assassin wins:  301
# 81  =>  0.619 assassin wins:  841
# 82  =>  0.735 assassin wins:  844
# 83  =>  0.411 assassin wins:  407
# 84  =>  0.372 assassin wins:  57
# 85  =>  0.79 assassin wins:  0
# 86  =>  0.346 assassin wins:  208
# 87  =>  0.668 assassin wins:  634
# 88  =>  0.651 assassin wins:  304
# 89  =>  0.252 assassin wins:  679
# 90  =>  0.641 assassin wins:  79
# 91  =>  0.097 assassin wins:  857
# 92  =>  0.431 assassin wins:  465
# 93  =>  0.208 assassin wins:  69
# 94  =>  0.521 assassin wins:  635
# 95  =>  0.029 assassin wins:  976
# 96  =>  0.375 assassin wins:  584
# 97  =>  0.589 assassin wins:  438
# 98  =>  0.089 assassin wins:  798
# 99  =>  0.405 assassin wins:  437
# 100  =>  0.613 assassin wins:  417
# 101  =>  0.31 assassin wins:  390
# 102  =>  0.444 assassin wins:  241
# 103  =>  0.51 assassin wins:  504
# 104  =>  0.878 assassin wins:  925
# 105  =>  0.367 assassin wins:  106
# 106  =>  0.333 assassin wins:  546
# 107  =>  0.335 assassin wins:  343
# 108  =>  0.545 assassin wins:  312
# 109  =>  0.574 assassin wins:  291
# 110  =>  0.546 assassin wins:  277
# 111  =>  0.252 assassin wins:  316
# 112  =>  0.386 assassin wins:  203
# 113  =>  0.641 assassin wins:  594
# 114  =>  0.357 assassin wins:  593
# 115  =>  0.738 assassin wins:  643
# 116  =>  0.663 assassin wins:  592
# 117  =>  0.635 assassin wins:  649
# 118  =>  0.564 assassin wins:  402
# 119  =>  0.439 assassin wins:  424
# 120  =>  0.711 assassin wins:  333
# 121  =>  0.289 assassin wins:  841
# 122  =>  0.594 assassin wins:  430
# 123  =>  0.079 assassin wins:  935
# 124  =>  0.194 assassin wins:  799
# 125  =>  0.547 assassin wins:  358
# 126  =>  0.191 assassin wins:  786
# 127  =>  0.393 assassin wins:  571
# 128  =>  0.551 assassin wins:  143
# 129  =>  0.864 assassin wins:  840
# 130  =>  0.578 assassin wins:  274
# 131  =>  0.717 assassin wins:  719
# 132  =>  0.204 assassin wins:  1000
# 133  =>  0.567 assassin wins:  544
# 134  =>  0.317 assassin wins:  802
# 135  =>  0.385 assassin wins:  786
# 136  =>  0.98 assassin wins:  892
# 137  =>  0.056 assassin wins:  989
# 138  =>  0.553 assassin wins:  540
# 139  =>  0.646 assassin wins:  570
# 140  =>  0.652 assassin wins:  698
# 141  =>  0.698 assassin wins:  427
# 142  =>  0.427 assassin wins:  928
# 143  =>  0.571 assassin wins:  456
# 144  =>  0.184 assassin wins:  763
# 145  =>  0.563 assassin wins:  247
# 146  =>  0.203 assassin wins:  746
# 147  =>  0.363 assassin wins:  1000
# 148  =>  0.187 assassin wins:  0
# 149  =>  0.242 assassin wins:  808
# 150  =>  0.224 assassin wins:  593
# 151  =>  0.728 assassin wins:  850
# 152  =>  0.006 assassin wins:  1000
# 153  =>  0.664 assassin wins:  771
# 154  =>  0.524 assassin wins:  274
# 155  =>  0.27 assassin wins:  660
# 156  =>  0.571 assassin wins:  439
# 157  =>  0.996 assassin wins:  906
# 158  =>  0.739 assassin wins:  814
# 159  =>  0.595 assassin wins:  148
# 160  =>  0.542 assassin wins:  343
# 161  =>  0.484 assassin wins:  532
# 162  =>  0.686 assassin wins:  298
# 163  =>  0.494 assassin wins:  312
# 164  =>  0.039 assassin wins:  999
# 165  =>  0.391 assassin wins:  359
# 166  =>  0.173 assassin wins:  978
# 167  =>  0.544 assassin wins:  752
# 168  =>  0.488 assassin wins:  208
# 169  =>  0.389 assassin wins:  245
# 170  =>  0.84 assassin wins:  793
# 171  =>  0.39 assassin wins:  943
# 172  =>  0.774 assassin wins:  270
# 173  =>  0.587 assassin wins:  656
# 174  =>  0.452 assassin wins:  510
# 175  =>  0.315 assassin wins:  1000
# 176  =>  0.688 assassin wins:  0
# 177  =>  0.575 assassin wins:  963
# 178  =>  0.464 assassin wins:  577
# 179  =>  0.297 assassin wins:  254
# 180  =>  0.567 assassin wins:  474
# 181  =>  0.236 assassin wins:  145
# 182  =>  0.245 assassin wins:  541
# 183  =>  0.81 assassin wins:  577
# 184  =>  0.311 assassin wins:  711
# 185  =>  0.834 assassin wins:  619
# 186  =>  0.011 assassin wins:  960
# 187  =>  0.439 assassin wins:  607
# 188  =>  0.327 assassin wins:  1000
# 189  =>  0.534 assassin wins:  370
# 190  =>  0.1 assassin wins:  837
# 191  =>  0.614 assassin wins:  0
# 192  =>  0.557 assassin wins:  694
# 193  =>  0.196 assassin wins:  474
# 194  =>  0.37 assassin wins:  563
# 195  =>  0.566 assassin wins:  542
# 196  =>  0.887 assassin wins:  935
# 197  =>  0.614 assassin wins:  322
# 198  =>  0.789 assassin wins:  512
# 199  =>  0.574 assassin wins:  784
# 200  =>  0.412 assassin wins:  422
# 201  =>  0.024 assassin wins:  875
# 202  =>  0.512 assassin wins:  678
# 203  =>  0.806 assassin wins:  965
# 204  =>  0.375 assassin wins:  933
# 205  =>  0.571 assassin wins:  308
# 206  =>  0.05 assassin wins:  929
# 207  =>  0.569 assassin wins:  263
# 208  =>  0.201 assassin wins:  812
# 209  =>  0.402 assassin wins:  493
# 210  =>  0.516 assassin wins:  675
# 211  =>  0.464 assassin wins:  135
# 212  =>  0.431 assassin wins:  572
# 213  =>  0.474 assassin wins:  408
# 214  =>  0.275 assassin wins:  808
# 215  =>  0.128 assassin wins:  724
# 216  =>  0.445 assassin wins:  410
# 217  =>  0.147 assassin wins:  504
# 218  =>  0.411 assassin wins:  480
# 219  =>  0.426 assassin wins:  449
# 220  =>  0.496 assassin wins:  426
# 221  =>  0.499 assassin wins:  791
# 222  =>  0.413 assassin wins:  309
# 223  =>  0.247 assassin wins:  239
# 224  =>  0.436 assassin wins:  181
# 225  =>  0.0 assassin wins:  914
# 226  =>  0.47 assassin wins:  344
# 227  =>  0.6 assassin wins:  514
# 228  =>  0.545 assassin wins:  588
# 229  =>  0.591 assassin wins:  445
# 230  =>  0.634 assassin wins:  935
# 231  =>  0.563 assassin wins:  435
# 232  =>  0.441 assassin wins:  404
# 233  =>  0.087 assassin wins:  928
# 234  =>  0.011 assassin wins:  993
# 235  =>  0.57 assassin wins:  293
# 236  =>  0.372 assassin wins:  241
# 237  =>  0.697 assassin wins:  681
# 238  =>  0.444 assassin wins:  822
# 239  =>  0.75 assassin wins:  894
# 240  =>  0.04 assassin wins:  991
# 241  =>  0.657 assassin wins:  548
# 242  =>  0.889 assassin wins:  725
# 243  =>  0.226 assassin wins:  637
# 244  =>  0.054 assassin wins:  895
# 245  =>  0.042 assassin wins:  918
# 246  =>  0.037 assassin wins:  977
# 247  =>  0.123 assassin wins:  1000
# 248  =>  0.497 assassin wins:  438
# 249  =>  0.625 assassin wins:  256
# 250  =>  0.034 assassin wins:  984
# 251  =>  0.349 assassin wins:  577
# 252  =>  1.0 assassin wins:  957
# 253  =>  0.355 assassin wins:  422
# 254  =>  0.48 assassin wins:  165
# 255  =>  0.555 assassin wins:  203
# 256  =>  0.644 assassin wins:  364
# 257  =>  0.779 assassin wins:  795
# 258  =>  0.619 assassin wins:  711
# 259  =>  0.234 assassin wins:  818
# 260  =>  0.498 assassin wins:  449
# 261  =>  0.395 assassin wins:  357
# 262  =>  0.718 assassin wins:  253
# 263  =>  0.812 assassin wins:  160
# 264  =>  0.602 assassin wins:  811
# 265  =>  0.573 assassin wins:  0
# 266  =>  0.181 assassin wins:  615
# 267  =>  0.183 assassin wins:  844
# 268  =>  0.237 assassin wins:  142
# 269  =>  0.538 assassin wins:  227
# 270  =>  0.363 assassin wins:  541
# 271  =>  0.244 assassin wins:  384
# 272  =>  0.092 assassin wins:  551
# 273  =>  0.543 assassin wins:  292
# 274  =>  0.268 assassin wins:  840
# 275  =>  0.301 assassin wins:  319
# 276  =>  0.017 assassin wins:  1000
# 277  =>  0.504 assassin wins:  707
# 278  =>  0.324 assassin wins:  592
# 279  =>  0.297 assassin wins:  838
# 280  =>  0.414 assassin wins:  357
# 281  =>  0.254 assassin wins:  832
# 282  =>  0.257 assassin wins:  752
# 283  =>  0.625 assassin wins:  322
# 284  =>  0.93 assassin wins:  791
# 285  =>  0.603 assassin wins:  0
# 286  =>  0.776 assassin wins:  63
# 287  =>  0.811 assassin wins:  660
# 288  =>  0.656 assassin wins:  648
# 289  =>  0.67 assassin wins:  747
# 290  =>  0.511 assassin wins:  366
# 291  =>  0.182 assassin wins:  917
# 292  =>  0.132 assassin wins:  1000
# 293  =>  0.459 assassin wins:  433
# 294  =>  0.438 assassin wins:  730
# 295  =>  0.317 assassin wins:  844
# 296  =>  0.423 assassin wins:  444
# 297  =>  0.998 assassin wins:  958
# 298  =>  0.004 assassin wins:  1000
# 299  =>  0.528 assassin wins:  841
# 300  =>  0.996 assassin wins:  992
# 301  =>  0.285 assassin wins:  701
# 302  =>  0.534 assassin wins:  330
# 303  =>  0.855 assassin wins:  265
# 304  =>  0.415 assassin wins:  461
# 305  =>  0.199 assassin wins:  657
# 306  =>  0.452 assassin wins:  685
# 307  =>  0.686 assassin wins:  180
# 308  =>  0.639 assassin wins:  258
# 309  =>  0.467 assassin wins:  344
# 310  =>  0.561 assassin wins:  7
# 311  =>  0.464 assassin wins:  213
# 312  =>  0.617 assassin wins:  876
# 313  =>  0.663 assassin wins:  273
# 314  =>  0.25 assassin wins:  834
# 315  =>  0.292 assassin wins:  796
# 316  =>  0.523 assassin wins:  131
# 317  =>  0.107 assassin wins:  953
# 318  =>  0.386 assassin wins:  500
# 319  =>  0.562 assassin wins:  178
# 320  =>  0.706 assassin wins:  752
# 321  =>  0.061 assassin wins:  995
# 322  =>  0.434 assassin wins:  633
# 323  =>  0.144 assassin wins:  960
# 324  =>  0.128 assassin wins:  948
# 325  =>  0.639 assassin wins:  469
# 326  =>  0.615 assassin wins:  629
# 327  =>  0.239 assassin wins:  561
# 328  =>  0.355 assassin wins:  514
# 329  =>  0.444 assassin wins:  343
# 330  =>  0.468 assassin wins:  638
# 331  =>  0.311 assassin wins:  0
# 332  =>  0.006 assassin wins:  997
# 333  =>  0.344 assassin wins:  485
# 334  =>  0.47 assassin wins:  376
# 335  =>  0.478 assassin wins:  438
# 336  =>  0.397 assassin wins:  806
# 337  =>  0.511 assassin wins:  477
# 338  =>  0.749 assassin wins:  466
# 339  =>  0.506 assassin wins:  667
# 340  =>  0.32 assassin wins:  134
# 341  =>  0.842 assassin wins:  696
# 342  =>  0.773 assassin wins:  493
# 343  =>  0.199 assassin wins:  976
# 344  =>  0.852 assassin wins:  960
# 345  =>  0.06 assassin wins:  972
# 346  =>  0.278 assassin wins:  763
# 347  =>  0.553 assassin wins:  493
# 348  =>  0.856 assassin wins:  792
# 349  =>  0.746 assassin wins:  527
# 350  =>  0.702 assassin wins:  939
# 351  =>  0.134 assassin wins:  766
# 352  =>  0.456 assassin wins:  682
# 353  =>  0.522 assassin wins:  149
# 354  =>  0.45 assassin wins:  382
# 355  =>  0.413 assassin wins:  394
# 356  =>  0.554 assassin wins:  510
# 357  =>  0.583 assassin wins:  507
# 358  =>  0.414 assassin wins:  687
# 359  =>  0.125 assassin wins:  564
# 360  =>  0.606 assassin wins:  642
# 361  =>  0.641 assassin wins:  397
# 362  =>  0.468 assassin wins:  913
# 363  =>  0.623 assassin wins:  84
# 364  =>  0.255 assassin wins:  658
# 365  =>  0.78 assassin wins:  711
# 366  =>  0.731 assassin wins:  537
# 367  =>  0.24 assassin wins:  643
# 368  =>  0.748 assassin wins:  766
# 369  =>  0.341 assassin wins:  600
# 370  =>  0.45 assassin wins:  554
# 371  =>  0.703 assassin wins:  910
# 372  =>  0.524 assassin wins:  500
# 373  =>  0.024 assassin wins:  998
# 374  =>  0.772 assassin wins:  393
# 375  =>  0.384 assassin wins:  499
# 376  =>  0.358 assassin wins:  552
# 377  =>  0.22 assassin wins:  78
# 378  =>  0.557 assassin wins:  347
# 379  =>  0.297 assassin wins:  998
# 380  =>  0.485 assassin wins:  352
# 381  =>  0.699 assassin wins:  269
# 382  =>  0.455 assassin wins:  681
# 383  =>  0.035 assassin wins:  876
# 384  =>  0.498 assassin wins:  383
# 385  =>  0.82 assassin wins:  220
# 386  =>  0.018 assassin wins:  996
# 387  =>  0.498 assassin wins:  279
# 388  =>  0.663 assassin wins:  726
# 389  =>  0.542 assassin wins:  602
# 390  =>  0.492 assassin wins:  641
# 391  =>  0.311 assassin wins:  637
# 392  =>  0.33 assassin wins:  701
# 393  =>  0.533 assassin wins:  527
# 394  =>  0.392 assassin wins:  636
# 395  =>  0.582 assassin wins:  124
# 396  =>  0.05 assassin wins:  1000
# 397  =>  0.91 assassin wins:  290
# 398  =>  0.679 assassin wins:  570
# 399  =>  0.584 assassin wins:  623
# 400  =>  0.456 assassin wins:  571
# 401  =>  0.488 assassin wins:  434
# 402  =>  0.368 assassin wins:  332
# 403  =>  0.867 assassin wins:  925
# 404  =>  0.328 assassin wins:  995
# 405  =>  0.522 assassin wins:  306
# 406  =>  0.68 assassin wins:  572
# 407  =>  0.583 assassin wins:  939
# 408  =>  0.713 assassin wins:  485
# 409  =>  0.845 assassin wins:  873
# 410  =>  0.274 assassin wins:  612
# 411  =>  0.684 assassin wins:  824
# 412  =>  0.174 assassin wins:  857
# 413  =>  0.911 assassin wins:  336
# 414  =>  0.225 assassin wins:  700
# 415  =>  0.216 assassin wins:  857
# 416  =>  0.335 assassin wins:  31
# 417  =>  0.204 assassin wins:  523
# 418  =>  0.258 assassin wins:  547
# 419  =>  0.013 assassin wins:  969
# 420  =>  0.479 assassin wins:  630
# 421  =>  0.561 assassin wins:  385
# 422  =>  0.038 assassin wins:  975
# 423  =>  0.411 assassin wins:  295
# 424  =>  0.426 assassin wins:  344
# 425  =>  0.306 assassin wins:  560
# 426  =>  0.537 assassin wins:  522
# 427  =>  0.805 assassin wins:  342
# 428  =>  0.583 assassin wins:  375
# 429  =>  0.818 assassin wins:  0
# 430  =>  0.758 assassin wins:  878
# 431  =>  0.111 assassin wins:  817
# 432  =>  0.91 assassin wins:  350
# 433  =>  0.368 assassin wins:  390
# 434  =>  0.664 assassin wins:  502
# 435  =>  0.454 assassin wins:  567
# 436  =>  0.116 assassin wins:  665
# 437  =>  0.716 assassin wins:  274
# 438  =>  0.697 assassin wins:  418
# 439  =>  0.859 assassin wins:  890
# 440  =>  0.176 assassin wins:  555
# 441  =>  0.381 assassin wins:  826
# 442  =>  0.248 assassin wins:  744
# 443  =>  0.514 assassin wins:  244
# 444  =>  0.366 assassin wins:  631
# 445  =>  0.523 assassin wins:  233
# 446  =>  0.536 assassin wins:  317
# 447  =>  0.395 assassin wins:  440
# 448  =>  0.538 assassin wins:  199
# 449  =>  0.954 assassin wins:  958
# 450  =>  0.624 assassin wins:  530
# 451  =>  0.19 assassin wins:  833
# 452  =>  0.437 assassin wins:  691
# 453  =>  0.08 assassin wins:  987
# 454  =>  0.863 assassin wins:  288
# 455  =>  0.65 assassin wins:  81
# 456  =>  0.295 assassin wins:  625
# 457  =>  0.316 assassin wins:  148
# 458  =>  0.434 assassin wins:  669
# 459  =>  0.616 assassin wins:  506
# 460  =>  0.605 assassin wins:  393
# 461  =>  0.643 assassin wins:  474
# 462  =>  0.554 assassin wins:  435
# 463  =>  0.457 assassin wins:  933
# 464  =>  0.864 assassin wins:  979
# 465  =>  0.51 assassin wins:  204
# 466  =>  0.024 assassin wins:  944
# 467  =>  0.675 assassin wins:  430
# 468  =>  0.076 assassin wins:  981
# 469  =>  0.102 assassin wins:  992
# 470  =>  0.787 assassin wins:  159
# 471  =>  0.143 assassin wins:  699
# 472  =>  0.219 assassin wins:  464
# 473  =>  0.568 assassin wins:  212
# 474  =>  0.553 assassin wins:  294
# 475  =>  0.588 assassin wins:  586
# 476  =>  0.704 assassin wins:  643
# 477  =>  0.587 assassin wins:  0
# 478  =>  0.662 assassin wins:  356
# 479  =>  0.722 assassin wins:  850
# 480  =>  0.522 assassin wins:  525
# 481  =>  0.27 assassin wins:  690
# 482  =>  0.565 assassin wins:  522
# 483  =>  0.283 assassin wins:  592
# 484  =>  0.371 assassin wins:  383
# 485  =>  0.258 assassin wins:  624
# 486  =>  0.539 assassin wins:  464
# 487  =>  0.588 assassin wins:  401
# 488  =>  0.253 assassin wins:  150
# 489  =>  0.133 assassin wins:  882
# 490  =>  0.711 assassin wins:  183
# 491  =>  0.323 assassin wins:  272
# 492  =>  0.393 assassin wins:  797
# 493  =>  0.769 assassin wins:  555
# 494  =>  0.416 assassin wins:  339
# 495  =>  0.737 assassin wins:  559
# 496  =>  0.359 assassin wins:  593
# 497  =>  0.282 assassin wins:  734
# 498  =>  0.696 assassin wins:  965
# 499  =>  0.478 assassin wins:  191
# 500  =>  0.621 assassin wins:  432
# 501  =>  0.782 assassin wins:  692
# 502  =>  0.299 assassin wins:  771
# 503  =>  0.666 assassin wins:  146
# 504  =>  0.21 assassin wins:  668
# 505  =>  0.353 assassin wins:  985
# 506  =>  0.673 assassin wins:  762
# 507  =>  0.058 assassin wins:  973
# 508  =>  0.809 assassin wins:  597
# 509  =>  0.338 assassin wins:  409
# 510  =>  0.763 assassin wins:  597
# 511  =>  0.389 assassin wins:  546
# 512  =>  0.651 assassin wins:  557
# 513  =>  0.339 assassin wins:  999
# 514  =>  0.431 assassin wins:  897
# 515  =>  0.446 assassin wins:  499
# 516  =>  0.684 assassin wins:  662
# 517  =>  0.852 assassin wins:  967
# 518  =>  0.809 assassin wins:  918
# 519  =>  0.0 assassin wins:  972
# 520  =>  0.094 assassin wins:  809
# 521  =>  0.285 assassin wins:  577
# 522  =>  0.212 assassin wins:  777
# 523  =>  0.613 assassin wins:  262
# 524  =>  0.522 assassin wins:  989
# 525  =>  0.446 assassin wins:  203
# 526  =>  0.46 assassin wins:  550
# 527  =>  0.528 assassin wins:  623
# 528  =>  0.376 assassin wins:  759
# 529  =>  0.364 assassin wins:  640
# 530  =>  0.132 assassin wins:  768
# 531  =>  0.759 assassin wins:  476
# 532  =>  0.551 assassin wins:  378
# 533  =>  0.858 assassin wins:  202
# 534  =>  0.627 assassin wins:  519
# 535  =>  0.513 assassin wins:  497
# 536  =>  0.155 assassin wins:  871
# 537  =>  0.57 assassin wins:  184
# 538  =>  0.401 assassin wins:  0
# 539  =>  0.25 assassin wins:  0
# 540  =>  0.579 assassin wins:  487
# 541  =>  0.014 assassin wins:  938
# 542  =>  0.551 assassin wins:  661
# 543  =>  0.564 assassin wins:  275
# 544  =>  0.436 assassin wins:  494
# 545  =>  0.859 assassin wins:  557
# 546  =>  0.327 assassin wins:  284
# 547  =>  0.696 assassin wins:  579
# 548  =>  0.737 assassin wins:  0
# 549  =>  0.395 assassin wins:  412
# 550  =>  0.515 assassin wins:  142
# 551  =>  0.415 assassin wins:  657
# 552  =>  0.457 assassin wins:  608
# 553  =>  0.329 assassin wins:  728
# 554  =>  0.418 assassin wins:  136
# 555  =>  0.102 assassin wins:  874
# 556  =>  0.288 assassin wins:  595
# 557  =>  0.689 assassin wins:  113
# 558  =>  0.362 assassin wins:  726
# 559  =>  0.345 assassin wins:  470
# 560  =>  0.5 assassin wins:  319
# 561  =>  0.884 assassin wins:  933
# 562  =>  0.628 assassin wins:  506
# 563  =>  0.602 assassin wins:  987
# 564  =>  0.296 assassin wins:  206
# 565  =>  0.12 assassin wins:  785
# 566  =>  0.455 assassin wins:  659
# 567  =>  0.605 assassin wins:  640
# 568  =>  0.617 assassin wins:  950
# 569  =>  0.447 assassin wins:  226
# 570  =>  0.437 assassin wins:  662
# 571  =>  0.198 assassin wins:  424
# 572  =>  0.593 assassin wins:  245
# 573  =>  0.818 assassin wins:  522
# 574  =>  0.446 assassin wins:  528
# 575  =>  0.767 assassin wins:  350
# 576  =>  0.937 assassin wins:  973
# 577  =>  0.452 assassin wins:  387
# 578  =>  0.699 assassin wins:  351
# 579  =>  0.636 assassin wins:  260
# 580  =>  0.145 assassin wins:  765
# 581  =>  0.277 assassin wins:  665
# 582  =>  0.249 assassin wins:  611
# 583  =>  0.467 assassin wins:  316
# 584  =>  0.489 assassin wins:  869
# 585  =>  0.333 assassin wins:  310
# 586  =>  0.592 assassin wins:  254
# 587  =>  0.175 assassin wins:  771
# 588  =>  0.287 assassin wins:  432
# 589  =>  0.949 assassin wins:  941
# 590  =>  0.157 assassin wins:  891
# 591  =>  0.137 assassin wins:  867
# 592  =>  0.436 assassin wins:  525
# 593  =>  0.291 assassin wins:  738
# 594  =>  0.395 assassin wins:  657
# 595  =>  0.805 assassin wins:  786
# 596  =>  0.491 assassin wins:  68
# 597  =>  0.402 assassin wins:  212
# 598  =>  0.05 assassin wins:  973
# 599  =>  0.343 assassin wins:  395
# 600  =>  0.716 assassin wins:  527
# 601  =>  0.343 assassin wins:  495
# 602  =>  0.292 assassin wins:  572
# 603  =>  0.573 assassin wins:  392
# 604  =>  0.922 assassin wins:  728
# 605  =>  0.124 assassin wins:  847
# 606  =>  0.663 assassin wins:  621
# 607  =>  0.564 assassin wins:  389
# 608  =>  0.198 assassin wins:  779
# 609  =>  0.614 assassin wins:  592
# 610  =>  0.877 assassin wins:  978
# 611  =>  0.765 assassin wins:  837
# 612  =>  0.344 assassin wins:  700
# 613  =>  0.643 assassin wins:  512
# 614  =>  0.57 assassin wins:  189
# 615  =>  0.634 assassin wins:  124
# 616  =>  0.178 assassin wins:  621
# 617  =>  0.822 assassin wins:  954
# 618  =>  0.503 assassin wins:  305
# 619  =>  0.268 assassin wins:  285
# 620  =>  0.789 assassin wins:  585
# 621  =>  0.358 assassin wins:  431
# 622  =>  0.836 assassin wins:  763
# 623  =>  0.647 assassin wins:  617
# 624  =>  0.32 assassin wins:  0
# 625  =>  0.53 assassin wins:  369
# 626  =>  0.419 assassin wins:  206
# 627  =>  0.743 assassin wins:  170
# 628  =>  0.55 assassin wins:  463
# 629  =>  0.466 assassin wins:  735
# 630  =>  0.494 assassin wins:  797
# 631  =>  0.473 assassin wins:  515
# 632  =>  0.377 assassin wins:  464
# 633  =>  0.302 assassin wins:  491
# 634  =>  0.342 assassin wins:  345
# 635  =>  0.492 assassin wins:  304
# 636  =>  0.472 assassin wins:  510
# 637  =>  0.384 assassin wins:  291
# 638  =>  0.836 assassin wins:  626
# 639  =>  0.679 assassin wins:  764
# 640  =>  0.682 assassin wins:  581
# 641  =>  0.172 assassin wins:  733
# 642  =>  0.535 assassin wins:  377
# 643  =>  0.452 assassin wins:  620
# 644  =>  0.573 assassin wins:  445
# 645  =>  0.227 assassin wins:  917
# 646  =>  0.293 assassin wins:  279
# 647  =>  0.712 assassin wins:  264
# 648  =>  0.226 assassin wins:  606
# 649  =>  0.217 assassin wins:  1000
# 650  =>  0.418 assassin wins:  420
# 651  =>  0.287 assassin wins:  539
# 652  =>  0.54 assassin wins:  273
# 653  =>  0.647 assassin wins:  969
# 654  =>  0.402 assassin wins:  296
# 655  =>  0.464 assassin wins:  371
# 656  =>  0.413 assassin wins:  375
# 657  =>  0.307 assassin wins:  246
# 658  =>  0.491 assassin wins:  284
# 659  =>  0.238 assassin wins:  533
# 660  =>  0.569 assassin wins:  708
# 661  =>  0.603 assassin wins:  558
# 662  =>  0.538 assassin wins:  600
# 663  =>  0.48 assassin wins:  159
# 664  =>  0.015 assassin wins:  995
# 665  =>  0.489 assassin wins:  360
# 666  =>  0.53 assassin wins:  133
# 667  =>  0.502 assassin wins:  965
# 668  =>  0.7 assassin wins:  563
# 669  =>  0.8 assassin wins:  560
# 670  =>  0.871 assassin wins:  566
# 671  =>  0.724 assassin wins:  856
# 672  =>  0.033 assassin wins:  999
# 673  =>  0.217 assassin wins:  626
# 674  =>  0.249 assassin wins:  105
# 675  =>  0.591 assassin wins:  298
# 676  =>  0.254 assassin wins:  880
# 677  =>  0.559 assassin wins:  367
# 678  =>  0.375 assassin wins:  368
# 679  =>  0.38 assassin wins:  477
# 680  =>  0.369 assassin wins:  392
# 681  =>  0.695 assassin wins:  523
# 682  =>  0.55 assassin wins:  536
# 683  =>  0.431 assassin wins:  799
# 684  =>  0.444 assassin wins:  342
# 685  =>  0.377 assassin wins:  473
# 686  =>  0.075 assassin wins:  996
# 687  =>  0.696 assassin wins:  349
# 688  =>  0.788 assassin wins:  342
# 689  =>  0.27 assassin wins:  719
# 690  =>  0.353 assassin wins:  739
# 691  =>  0.613 assassin wins:  308
# 692  =>  0.529 assassin wins:  344
# 693  =>  0.6 assassin wins:  116
# 694  =>  0.823 assassin wins:  788
# 695  =>  0.303 assassin wins:  548
# 696  =>  0.264 assassin wins:  680
# 697  =>  0.534 assassin wins:  147
# 698  =>  0.656 assassin wins:  587
# 699  =>  0.117 assassin wins:  822
# 700  =>  0.33 assassin wins:  495
# 701  =>  0.755 assassin wins:  117
# 702  =>  0.778 assassin wins:  239
# 703  =>  0.747 assassin wins:  645
# 704  =>  0.226 assassin wins:  961
# 705  =>  0.22 assassin wins:  417
# 706  =>  0.168 assassin wins:  675
# 707  =>  0.441 assassin wins:  392
# 708  =>  0.316 assassin wins:  147
# 709  =>  0.509 assassin wins:  174
# 710  =>  0.69 assassin wins:  208
# 711  =>  0.205 assassin wins:  896
# 712  =>  0.521 assassin wins:  377
# 713  =>  0.471 assassin wins:  472
# 714  =>  0.658 assassin wins:  800
# 715  =>  0.543 assassin wins:  270
# 716  =>  0.683 assassin wins:  737
# 717  =>  0.442 assassin wins:  647
# 718  =>  0.425 assassin wins:  775
# 719  =>  0.658 assassin wins:  483
# 720  =>  0.294 assassin wins:  406
# 721  =>  0.651 assassin wins:  356
# 722  =>  0.425 assassin wins:  586
# 723  =>  0.525 assassin wins:  859
# 724  =>  0.423 assassin wins:  968
# 725  =>  0.806 assassin wins:  0
# 726  =>  0.628 assassin wins:  472
# 727  =>  0.738 assassin wins:  627
# 728  =>  0.742 assassin wins:  910
# 729  =>  0.414 assassin wins:  0
# 730  =>  0.725 assassin wins:  588
# 731  =>  0.681 assassin wins:  475
# 732  =>  0.383 assassin wins:  468
# 733  =>  0.768 assassin wins:  608
# 734  =>  0.446 assassin wins:  413
# 735  =>  0.144 assassin wins:  888
# 736  =>  0.556 assassin wins:  0
# 737  =>  0.796 assassin wins:  436
# 738  =>  0.646 assassin wins:  946
# 739  =>  0.324 assassin wins:  252
# 740  =>  0.344 assassin wins:  195
# 741  =>  0.043 assassin wins:  923
# 742  =>  0.041 assassin wins:  997
# 743  =>  0.303 assassin wins:  335
# 744  =>  0.544 assassin wins:  427
# 745  =>  0.576 assassin wins:  331
# 746  =>  0.326 assassin wins:  54
# 747  =>  0.277 assassin wins:  792
# 748  =>  0.23 assassin wins:  729
# 749  =>  0.015 assassin wins:  998
# 750  =>  0.731 assassin wins:  660
# 751  =>  0.501 assassin wins:  485
# 752  =>  0.693 assassin wins:  470
# 753  =>  0.06 assassin wins:  997
# 754  =>  0.624 assassin wins:  696
# 755  =>  0.949 assassin wins:  831
# 756  =>  0.355 assassin wins:  296
# 757  =>  0.254 assassin wins:  547
# 758  =>  0.616 assassin wins:  542
# 759  =>  0.559 assassin wins:  389
# 760  =>  0.302 assassin wins:  1000
# 761  =>  0.464 assassin wins:  341
# 762  =>  0.417 assassin wins:  469
# 763  =>  0.375 assassin wins:  703
# 764  =>  0.769 assassin wins:  297
# 765  =>  0.463 assassin wins:  578
# 766  =>  0.285 assassin wins:  940
# 767  =>  0.652 assassin wins:  388
# 768  =>  0.453 assassin wins:  495
# 769  =>  0.837 assassin wins:  155
# 770  =>  0.311 assassin wins:  423
# 771  =>  0.479 assassin wins:  279
# 772  =>  0.609 assassin wins:  446
# 773  =>  0.441 assassin wins:  866
# 774  =>  0.536 assassin wins:  0
# 775  =>  0.293 assassin wins:  477
# 776  =>  0.517 assassin wins:  475
# 777  =>  0.3 assassin wins:  773
# 778  =>  0.685 assassin wins:  534
# 779  =>  0.674 assassin wins:  795
# 780  =>  0.529 assassin wins:  284
# 781  =>  0.545 assassin wins:  511
# 782  =>  0.232 assassin wins:  387
# 783  =>  0.629 assassin wins:  662
# 784  =>  0.303 assassin wins:  385
# 785  =>  0.353 assassin wins:  349
# 786  =>  0.521 assassin wins:  219
# 787  =>  0.743 assassin wins:  240
# 788  =>  0.429 assassin wins:  409
# 789  =>  0.314 assassin wins:  394
# 790  =>  0.666 assassin wins:  615
# 791  =>  0.36 assassin wins:  522
# 792  =>  0.104 assassin wins:  906
# 793  =>  0.919 assassin wins:  887
# 794  =>  0.118 assassin wins:  882
# 795  =>  0.505 assassin wins:  53
# 796  =>  0.497 assassin wins:  375
# 797  =>  0.367 assassin wins:  937
# 798  =>  0.629 assassin wins:  465
# 799  =>  0.495 assassin wins:  482
# 800  =>  0.728 assassin wins:  687
# 801  =>  0.433 assassin wins:  491
# 802  =>  0.209 assassin wins:  765
# 803  =>  0.339 assassin wins:  162
# 804  =>  0.295 assassin wins:  807
# 805  =>  0.472 assassin wins:  303
# 806  =>  0.316 assassin wins:  297
# 807  =>  0.53 assassin wins:  838
# 808  =>  0.752 assassin wins:  397
# 809  =>  0.541 assassin wins:  364
# 810  =>  0.591 assassin wins:  879
# 811  =>  0.432 assassin wins:  322
# 812  =>  0.338 assassin wins:  305
# 813  =>  0.615 assassin wins:  526
# 814  =>  0.403 assassin wins:  694
# 815  =>  0.671 assassin wins:  206
# 816  =>  0.655 assassin wins:  559
# 817  =>  0.492 assassin wins:  106
# 818  =>  0.526 assassin wins:  396
# 819  =>  0.577 assassin wins:  346
# 820  =>  0.401 assassin wins:  596
# 821  =>  0.81 assassin wins:  760
# 822  =>  0.462 assassin wins:  509
# 823  =>  0.655 assassin wins:  153
# 824  =>  0.311 assassin wins:  619
# 825  =>  0.639 assassin wins:  237
# 826  =>  0.672 assassin wins:  336
# 827  =>  0.012 assassin wins:  949
# 828  =>  0.491 assassin wins:  302
# 829  =>  0.15 assassin wins:  738
# 830  =>  0.638 assassin wins:  269
# 831  =>  0.352 assassin wins:  370
# 832  =>  0.636 assassin wins:  336
# 833  =>  0.216 assassin wins:  412
# 834  =>  1.0 assassin wins:  978
# 835  =>  0.264 assassin wins:  819
# 836  =>  0.612 assassin wins:  465
# 837  =>  0.349 assassin wins:  718
# 838  =>  0.546 assassin wins:  232
# 839  =>  0.513 assassin wins:  579
# 840  =>  0.434 assassin wins:  683
# 841  =>  0.571 assassin wins:  572
# 842  =>  0.497 assassin wins:  471
# 843  =>  0.511 assassin wins:  244
# 844  =>  0.88 assassin wins:  942
# 845  =>  0.549 assassin wins:  0
# 846  =>  0.694 assassin wins:  824
# 847  =>  0.634 assassin wins:  344
# 848  =>  0.742 assassin wins:  511
# 849  =>  0.517 assassin wins:  425
# 850  =>  0.093 assassin wins:  764
# 851  =>  0.426 assassin wins:  406
# 852  =>  0.021 assassin wins:  966
# 853  =>  0.671 assassin wins:  389
# 854  =>  0.32 assassin wins:  304
# 855  =>  0.329 assassin wins:  258
# 856  =>  0.308 assassin wins:  0
# 857  =>  0.512 assassin wins:  262
# 858  =>  0.63 assassin wins:  266
# 859  =>  0.67 assassin wins:  587
# 860  =>  0.7 assassin wins:  678
# 861  =>  0.027 assassin wins:  979
# 862  =>  0.582 assassin wins:  248
# 863  =>  0.738 assassin wins:  0
# 864  =>  0.178 assassin wins:  218
# 865  =>  0.913 assassin wins:  676
# 866  =>  0.422 assassin wins:  422
# 867  =>  0.325 assassin wins:  322
# 868  =>  0.178 assassin wins:  499
# 869  =>  0.608 assassin wins:  466
# 870  =>  0.295 assassin wins:  507
# 871  =>  0.405 assassin wins:  240
# 872  =>  0.022 assassin wins:  1000
# 873  =>  0.613 assassin wins:  511
# 874  =>  0.507 assassin wins:  145
# 875  =>  0.791 assassin wins:  757
# 876  =>  0.699 assassin wins:  450
# 877  =>  0.6 assassin wins:  457
# 878  =>  0.375 assassin wins:  318
# 879  =>  0.505 assassin wins:  375
# 880  =>  0.191 assassin wins:  793
# 881  =>  0.701 assassin wins:  402
# 882  =>  0.444 assassin wins:  369
# 883  =>  0.329 assassin wins:  839
# 884  =>  0.349 assassin wins:  800
# 885  =>  0.506 assassin wins:  534
# 886  =>  0.672 assassin wins:  645
# 887  =>  0.017 assassin wins:  999
# 888  =>  0.763 assassin wins:  193
# 889  =>  0.515 assassin wins:  438
# 890  =>  0.584 assassin wins:  575
# 891  =>  0.457 assassin wins:  437
# 892  =>  0.488 assassin wins:  539
# 893  =>  0.234 assassin wins:  734
# 894  =>  0.521 assassin wins:  411
# 895  =>  0.731 assassin wins:  522
# 896  =>  0.561 assassin wins:  582
# 897  =>  0.559 assassin wins:  557
# 898  =>  0.65 assassin wins:  272
# 899  =>  0.621 assassin wins:  826
# 900  =>  0.979 assassin wins:  958
# 901  =>  0.039 assassin wins:  998
# 902  =>  0.551 assassin wins:  311
# 903  =>  0.552 assassin wins:  507
# 904  =>  0.952 assassin wins:  963
# 905  =>  0.573 assassin wins:  625
# 906  =>  0.426 assassin wins:  370
# 907  =>  0.503 assassin wins:  35
# 908  =>  0.877 assassin wins:  720
# 909  =>  0.602 assassin wins:  209
# 910  =>  0.37 assassin wins:  501
# 911  =>  0.536 assassin wins:  403
# 912  =>  0.742 assassin wins:  322
# 913  =>  0.564 assassin wins:  151
# 914  =>  0.724 assassin wins:  221
# 915  =>  0.08 assassin wins:  990
# 916  =>  0.351 assassin wins:  587
# 917  =>  0.05 assassin wins:  642
# 918  =>  0.527 assassin wins:  444
# 919  =>  0.168 assassin wins:  893
# 920  =>  0.53 assassin wins:  535
# 921  =>  0.175 assassin wins:  674
# 922  =>  0.842 assassin wins:  873
# 923  =>  0.414 assassin wins:  821
# 924  =>  0.41 assassin wins:  368
# 925  =>  0.001 assassin wins:  998
# 926  =>  0.647 assassin wins:  128
# 927  =>  1.0 assassin wins:  955
# 928  =>  0.29 assassin wins:  0
# 929  =>  0.038 assassin wins:  941
# 930  =>  0.561 assassin wins:  384
# 931  =>  0.07 assassin wins:  986
# 932  =>  0.22 assassin wins:  406
# 933  =>  0.548 assassin wins:  745
# 934  =>  0.782 assassin wins:  677
# 935  =>  0.167 assassin wins:  595
# 936  =>  0.446 assassin wins:  492
# 937  =>  0.655 assassin wins:  620
